# %% [markdown]
# <a href="https://colab.research.google.com/github/sehwan12/AI2025/blob/main/%5BAI2025_Assignment%5D_CIFAR10_Classification_20102110.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CIFAR10 Classification

# %% [markdown]
# ## Import Packages

# %%
import sys
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# ### Data Preparation
# Use CIFAR10 handwriting dataset

# %%
cifar10 = tf.keras.datasets.cifar10

# %% [markdown]
# Prepare data for training

# %%
# train / test split
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# minmax normalization
x_train, x_test = x_train / 255.0, x_test / 255.0

# one-hot encoding
y_train = tf.keras.utils.to_categorical(y_train)
y_test = tf.keras.utils.to_categorical(y_test)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 105s 1us/step

# %% [markdown]
# # Compile and Train neural network

# %% [markdown]
# ## CNN Modeling
# Create a convolutional neural network

# %% [markdown]
# ### Goal
#
# Improve the provided basic CNN model and achieve CIFAR-10 **test accuracy ≥ 75%**.

# %% [markdown]
# Modify the network architecture!

# %%
import tensorflow as tf
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

# 1. 데이터 로드 및 전처리
cifar10 = tf.keras.datasets.cifar10
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# 정규화 (Normalization)
x_train, x_test = x_train / 255.0, x_test / 255.0

# One-hot Encoding
y_train = tf.keras.utils.to_categorical(y_train)
y_test = tf.keras.utils.to_categorical(y_test)

# 2. VGG 스타일 3-Block 구조
model = tf.keras.models.Sequential([
    # Block 1: 저수준 특징 추출 (32 필터)
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(32, 32, 3)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Dropout(0.2),

    # Block 2: 중수준 특징 추출 (64 필터)
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Dropout(0.3),

    # Block 3: 고수준 특징 추출 (128 필터)
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Dropout(0.4),

    # 분류기 (Classifier)
    tf.keras.layers.Flatten(), # 또는 tf.keras.layers.GlobalAveragePooling2D()
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(10, activation='softmax')
])

# 3. 모델 컴파일
model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

# 4. 학습이 3번(patience=3) 동안 개선되지 않으면 학습률을 1/10로 줄임
lr_reduction = ReduceLROnPlateau(monitor='val_loss',
                                 patience=3,
                                 verbose=1,
                                 factor=0.1,
                                 min_lr=0.00001)

# 학습이 10번 동안 개선되지 않으면 조기 종료
early_stopping = EarlyStopping(monitor='val_loss',
                               patience=10,
                               restore_best_weights=True)

# 5. 학습 수행
history = model.fit(
    x_train, y_train,
    epochs=50, # 조기 종료가 있으므로 넉넉하게 설정
    batch_size=64, # 배치 사이즈 설정 (메모리에 따라 조절 가능)
    validation_data=(x_test, y_test),
    callbacks=[lr_reduction, early_stopping]
)

# 6. 최종 평가
loss, accuracy = model.evaluate(x_test, y_test)
print(f"\nFinal Test Accuracy: {accuracy * 100:.2f}%")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 27s 20ms/step - accuracy: 0.3616 - loss: 2.0665 - val_accuracy: 0.5597 - val_loss: 1.2128 - learning_rate: 0.0010
# Epoch 2/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.6091 - loss: 1.0939 - val_accuracy: 0.6399 - val_loss: 1.0570 - learning_rate: 0.0010
# Epoch 3/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.6928 - loss: 0.8722 - val_accuracy: 0.7396 - val_loss: 0.7316 - learning_rate: 0.0010
# Epoch 4/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.7327 - loss: 0.7630 - val_accuracy: 0.7658 - val_loss: 0.6764 - learning_rate: 0.0010
# Epoch 5/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.7590 - loss: 0.6930 - val_accuracy: 0.7526 - val_loss: 0.7221 - learning_rate: 0.0010
# Epoch 6/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.7823 - loss: 0.6236 - val_accuracy: 0.7861 - val_loss: 0.6225 - learning_rate: 0.0010
# Epoch 7/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - accuracy: 0.7991 - loss: 0.5843 - val_accuracy: 0.7811 - val_loss: 0.6396 - learning_rate: 0.0010
# Epoch 8/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.8140 - loss: 0.5334 - val_accuracy: 0.8185 - val_loss: 0.5339 - learning_rate: 0.0010
# Epoch 9/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.8259 - loss: 0.4994 - val_accuracy: 0.8222 - val_loss: 0.5092 - learning_rate: 0.0010
# Epoch 10/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.8375 - loss: 0.4681 - val_accuracy: 0.8074 - val_loss: 0.5674 - learning_rate: 0.0010
# Epoch 11/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.8468 - loss: 0.4432 - val_accuracy: 0.8376 - val_loss: 0.4942 - learning_rate: 0.0010
# Epoch 12/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.8505 - loss: 0.4301 - val_accuracy: 0.8219 - val_loss: 0.5329 - learning_rate: 0.0010
# Epoch 13/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.8607 - loss: 0.3997 - val_accuracy: 0.7810 - val_loss: 0.6600 - learning_rate: 0.0010
# Epoch 14/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.8638 - loss: 0.3892 - val_accuracy: 0.8499 - val_loss: 0.4574 - learning_rate: 0.0010
# Epoch 15/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.8724 - loss: 0.3599 - val_accuracy: 0.8253 - val_loss: 0.5527 - learning_rate: 0.0010
# Epoch 16/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.8793 - loss: 0.3457 - val_accuracy: 0.8361 - val_loss: 0.4939 - learning_rate: 0.0010
# Epoch 17/50
# 779/782 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8831 - loss: 0.3325
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.8831 - loss: 0.3326 - val_accuracy: 0.8455 - val_loss: 0.4883 - learning_rate: 0.0010
# Epoch 18/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.8991 - loss: 0.2838 - val_accuracy: 0.8677 - val_loss: 0.4051 - learning_rate: 1.0000e-04
# Epoch 19/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9093 - loss: 0.2611 - val_accuracy: 0.8692 - val_loss: 0.4010 - learning_rate: 1.0000e-04
# Epoch 20/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9139 - loss: 0.2434 - val_accuracy: 0.8701 - val_loss: 0.3993 - learning_rate: 1.0000e-04
# Epoch 21/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9194 - loss: 0.2314 - val_accuracy: 0.8718 - val_loss: 0.4021 - learning_rate: 1.0000e-04
# Epoch 22/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9220 - loss: 0.2249 - val_accuracy: 0.8720 - val_loss: 0.4032 - learning_rate: 1.0000e-04
# Epoch 23/50
# 781/782 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9238 - loss: 0.2153
# Epoch 23: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9238 - loss: 0.2153 - val_accuracy: 0.8732 - val_loss: 0.3997 - learning_rate: 1.0000e-04
# Epoch 24/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9249 - loss: 0.2101 - val_accuracy: 0.8748 - val_loss: 0.3994 - learning_rate: 1.0000e-05
# Epoch 25/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9260 - loss: 0.2102 - val_accuracy: 0.8759 - val_loss: 0.3990 - learning_rate: 1.0000e-05
# Epoch 26/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9255 - loss: 0.2084 - val_accuracy: 0.8756 - val_loss: 0.3989 - learning_rate: 1.0000e-05
# Epoch 27/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9276 - loss: 0.2048 - val_accuracy: 0.8762 - val_loss: 0.3993 - learning_rate: 1.0000e-05
# Epoch 28/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9259 - loss: 0.2073 - val_accuracy: 0.8746 - val_loss: 0.3990 - learning_rate: 1.0000e-05
# Epoch 29/50
# 780/782 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9286 - loss: 0.2008
# Epoch 29: ReduceLROnPlateau reducing learning rate to 1e-05.
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - accuracy: 0.9286 - loss: 0.2008 - val_accuracy: 0.8750 - val_loss: 0.3990 - learning_rate: 1.0000e-05
# Epoch 30/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9307 - loss: 0.1985 - val_accuracy: 0.8754 - val_loss: 0.3986 - learning_rate: 1.0000e-05
# Epoch 31/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9311 - loss: 0.2032 - val_accuracy: 0.8755 - val_loss: 0.3990 - learning_rate: 1.0000e-05
# Epoch 32/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - accuracy: 0.9291 - loss: 0.1960 - val_accuracy: 0.8759 - val_loss: 0.3984 - learning_rate: 1.0000e-05
# Epoch 33/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9321 - loss: 0.1977 - val_accuracy: 0.8761 - val_loss: 0.3981 - learning_rate: 1.0000e-05
# Epoch 34/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9266 - loss: 0.2055 - val_accuracy: 0.8763 - val_loss: 0.3999 - learning_rate: 1.0000e-05
# Epoch 35/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9261 - loss: 0.2023 - val_accuracy: 0.8768 - val_loss: 0.3982 - learning_rate: 1.0000e-05
# Epoch 36/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9293 - loss: 0.2007 - val_accuracy: 0.8763 - val_loss: 0.3984 - learning_rate: 1.0000e-05
# Epoch 37/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9282 - loss: 0.2047 - val_accuracy: 0.8766 - val_loss: 0.3985 - learning_rate: 1.0000e-05
# Epoch 38/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9306 - loss: 0.1947 - val_accuracy: 0.8767 - val_loss: 0.3982 - learning_rate: 1.0000e-05
# Epoch 39/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9283 - loss: 0.1972 - val_accuracy: 0.8762 - val_loss: 0.3985 - learning_rate: 1.0000e-05
# Epoch 40/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9313 - loss: 0.1948 - val_accuracy: 0.8758 - val_loss: 0.3991 - learning_rate: 1.0000e-05
# Epoch 41/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9302 - loss: 0.2002 - val_accuracy: 0.8765 - val_loss: 0.3988 - learning_rate: 1.0000e-05
# Epoch 42/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9317 - loss: 0.1932 - val_accuracy: 0.8759 - val_loss: 0.3987 - learning_rate: 1.0000e-05
# Epoch 43/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9293 - loss: 0.1993 - val_accuracy: 0.8768 - val_loss: 0.3991 - learning_rate: 1.0000e-05
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8743 - loss: 0.4004
#
# Final Test Accuracy: 87.61%

# %% [markdown]
# ## Evaluate neural network performance

# %%
model.evaluate(x_test,  y_test, verbose=2)
# Out:
# 313/313 - 2s - 5ms/step - accuracy: 0.8761 - loss: 0.3981
# [0.39814507961273193, 0.8761000037193298]

# %%
prob = model.predict(x_test[0:40], verbose=0)
pred = tf.argmax(prob, axis=1)

fig = plt.figure(figsize=(12, 18))
for i in range(40):
    subplot = fig.add_subplot(8, 5, i + 1)
    subplot.set_xticks([])
    subplot.set_yticks([])
    string = r'$\hat{y}$'
    subplot.set_title(f'$y$:{tf.argmax(y_test[i])}, {string}:{pred[i].numpy()}')
    subplot.imshow(tf.squeeze(x_test[i]))
plt.show()
true_label = tf.argmax(y_test[i]).numpy()
pred_label = pred[i].numpy()
plt.title(f"GT: {true_label}, Pred: {pred_label}")
loss, accuracy = model.evaluate(x_test, y_test, verbose=0)

# %%
loss, accuracy = model.evaluate(x_test, y_test, verbose=0)
print("Test Accuracy:", accuracy)
# Out:
# Test Accuracy: 0.8761000037193298
